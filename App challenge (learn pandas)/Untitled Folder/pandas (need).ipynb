# %%
import pandas as pd
import numpy as np

# %%
conda install -c conda-forge -y xlrd
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    -------- ------------------------------- 2.4/11.5 MB 11.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.7/11.5 MB 11.4 MB/s eta 0:00:01
#    ------------------------- -------------- 7.3/11.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.0/11.5 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 11.1 MB/s eta 0:00:00
# ...

# %%
df_class = pd.read_excel("dummy-class-1-of-2.xlsx", skiprows = 1)

# %%
# !pip install openpyxl

# %%
df_class
# Out:
#     Unnamed: 0                Name Student No Major Gender Test 2 (20%)  \
# 0            0      Braiden Henson  A3028967J   PHY      M      '18.96'
# 1            1        Gustavo Vang  A1282849W   CHM      F      '17.44'
# 2            2     Ronin Christian  A5408925A   PHY      M      '15.56'
# 3            3       Owen Anderson  A6973859L    LS      F      '16.36'
# 4            4          Kyla Young  A5410124H   PHY      M          NaN
# 5            5        Wyatt Oliver  A9568373Q   PHY      M     '14.088'
# 6            6       Essence Bauer  A6824244G    LS      M      '16.72'
# 7            7   Maryjane Sandoval  A9194090U    LS      F       '16.4'
# 8            8       Carl Trujillo  A4828364M    LS     NB      '13.68'
# 9            9         Halle Fritz  A4607700C    LS      F       '9.04'
# 10          10       Marie Hoffman  A7067766E    LS      F      '16.88'
# 11          11    Lilianna Kaufman  A5569996J    LS      M       '17.0'
# ...

# %%
df_class.head(3)
# Out:
#    Unnamed: 0             Name Student No Major Gender Test 2 (20%)  \
# 0           0   Braiden Henson  A3028967J   PHY      M      '18.96'
# 1           1     Gustavo Vang  A1282849W   CHM      F      '17.44'
# 2           2  Ronin Christian  A5408925A   PHY      M      '15.56'
#
#    Test 1 (30%)
# 0        20.205
# 1        13.470
# 2        18.366

# %%
df_class.tail(3)
# Out:
#     Unnamed: 0          Name Student No Major Gender Test 2 (20%)  \
# 32          32   Katie Ayers  A6867791C  CBIO      F      '10.28'
# 33          33  Tucker Sloan  A4080490P    LS      M      '15.04'
# 34          34  Carter Crane  A7667457P    LS      M     '13.816'
#
#     Test 1 (30%)
# 32        16.530
# 33        17.754
# 34        20.817

# %%
df_class.shape
# Out:
# (35, 7)

# %%
len(df_class)
# Out:
# 35

# %%
df_class.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Student No', 'Major', 'Gender', 'Test 2 (20%)',
#        'Test 1 (30%)'],
#       dtype='object')

# %%
df_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    35 non-null     int64
#  1   Name          35 non-null     object
#  2   Student No    35 non-null     object
#  3   Major         35 non-null     object
#  4   Gender        35 non-null     object
#  5   Test 2 (20%)  32 non-null     object
#  6   Test 1 (30%)  33 non-null     float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.0+ KB

# %%
df_class['Test 2 (20%)'].head(3)
# Out:
# 0    '18.96'
# 1    '17.44'
# 2    '15.56'
# Name: Test 2 (20%), dtype: object

# %%
df_class['Test 2 (20%)'] = df_class['Test 2 (20%)'].str.replace("'", "")
df_class['Test 2 (20%)'] = pd.to_numeric(df_class['Test 2 (20%)'])

# %%
df_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    35 non-null     int64
#  1   Name          35 non-null     object
#  2   Student No    35 non-null     object
#  3   Major         35 non-null     object
#  4   Gender        35 non-null     object
#  5   Test 2 (20%)  32 non-null     float64
#  6   Test 1 (30%)  33 non-null     float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 2.0+ KB

# %%
df_class.describe()
# Out:
#        Unnamed: 0  Test 2 (20%)  Test 1 (30%)
# count   35.000000     32.000000     33.000000
# mean    17.000000     15.405750     18.534455
# std     10.246951      2.229394      3.487934
# min      0.000000      9.040000     12.246000
# 25%      8.500000     14.360000     15.918000
# 50%     17.000000     15.820000     18.366000
# 75%     25.500000     16.880000     20.817000
# max     34.000000     18.960000     26.328000

# %%
df_class.describe(include="all")
# Out:
#         Unnamed: 0            Name Student No Major Gender  Test 2 (20%)  \
# count    35.000000              35         35    35     35     32.000000
# unique         NaN              35         35     4      3           NaN
# top            NaN  Braiden Henson  A3028967J    LS      M           NaN
# freq           NaN               1          1    14     16           NaN
# mean     17.000000             NaN        NaN   NaN    NaN     15.405750
# std      10.246951             NaN        NaN   NaN    NaN      2.229394
# min       0.000000             NaN        NaN   NaN    NaN      9.040000
# 25%       8.500000             NaN        NaN   NaN    NaN     14.360000
# 50%      17.000000             NaN        NaN   NaN    NaN     15.820000
# 75%      25.500000             NaN        NaN   NaN    NaN     16.880000
# max      34.000000             NaN        NaN   NaN    NaN     18.960000
#
#         Test 1 (30%)
# count      33.000000
# unique           NaN
# top              NaN
# ...

# %%
df_class['Test 1 (30%)'].mean()
# Out:
# np.float64(18.534454545454548)

# %%
df_class[['Test 1 (30%)', 'Test 2 (20%)']].mean()
# Out:
# Test 1 (30%)    18.534455
# Test 2 (20%)    15.405750
# dtype: float64

# %%
df_class['Major'].values
# Out:
# array(['PHY', 'CHM', 'PHY', 'LS', 'PHY', 'PHY', 'LS', 'LS', 'LS', 'LS',
#        'LS', 'LS', 'PHY', 'LS', 'CHM', 'PHY', 'CHM', 'PHY', 'CHM', 'CHM',
#        'PHY', 'CHM', 'LS', 'LS', 'LS', 'PHY', 'PHY', 'PHY', 'CHM', 'LS',
#        'CHM', 'PHY', 'CBIO', 'LS', 'LS'], dtype=object)

# %%
df_class['Major'].unique()
# Out:
# array(['PHY', 'CHM', 'LS', 'CBIO'], dtype=object)

# %%
df_class['Major'].value_counts()
# Out:
# Major
# LS      14
# PHY     12
# CHM      8
# CBIO     1
# Name: count, dtype: int64

# %%
df_class['Major'].value_counts().to_dict()
# Out:
# {'LS': 14, 'PHY': 12, 'CHM': 8, 'CBIO': 1}

# %%
df_class['Major'].value_counts().to_list()
# Out:
# [14, 12, 8, 1]

# %%
df_class['Major'].value_counts().index.to_list()
# Out:
# ['LS', 'PHY', 'CHM', 'CBIO']

# %%
df_class.drop(columns=['Unnamed: 0'])
# Out:
#                   Name Student No Major Gender  Test 2 (20%)  Test 1 (30%)
# 0       Braiden Henson  A3028967J   PHY      M        18.960        20.205
# 1         Gustavo Vang  A1282849W   CHM      F        17.440        13.470
# 2      Ronin Christian  A5408925A   PHY      M        15.560        18.366
# 3        Owen Anderson  A6973859L    LS      F        16.360        18.366
# 4           Kyla Young  A5410124H   PHY      M           NaN        15.306
# 5         Wyatt Oliver  A9568373Q   PHY      M        14.088        12.246
# 6        Essence Bauer  A6824244G    LS      M        16.720        16.530
# 7    Maryjane Sandoval  A9194090U    LS      F        16.400        18.981
# 8        Carl Trujillo  A4828364M    LS     NB        13.680        15.306
# 9          Halle Fritz  A4607700C    LS      F         9.040        17.754
# 10       Marie Hoffman  A7067766E    LS      F        16.880        19.593
# ...

# %%
df_class.head()
# Out:
#    Unnamed: 0             Name Student No Major Gender  Test 2 (20%)  \
# 0           0   Braiden Henson  A3028967J   PHY      M         18.96
# 1           1     Gustavo Vang  A1282849W   CHM      F         17.44
# 2           2  Ronin Christian  A5408925A   PHY      M         15.56
# 3           3    Owen Anderson  A6973859L    LS      F         16.36
# 4           4       Kyla Young  A5410124H   PHY      M           NaN
#
#    Test 1 (30%)
# 0        20.205
# 1        13.470
# 2        18.366
# 3        18.366
# 4        15.306

# %%
df_class = df_class.drop(columns=['Unnamed: 0'])

# %%
df_class.drop(columns=['Unnamed: 0'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df_class.drop(columns=['Unnamed: 0'], inplace=True)
#
# File ~\miniconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
print(df_class.head())
# Out:
#               Name Student No Major Gender  Test 2 (20%)  Test 1 (30%)
# 0   Braiden Henson  A3028967J   PHY      M         18.96        20.205
# 1     Gustavo Vang  A1282849W   CHM      F         17.44        13.470
# 2  Ronin Christian  A5408925A   PHY      M         15.56        18.366
# 3    Owen Anderson  A6973859L    LS      F         16.36        18.366
# 4       Kyla Young  A5410124H   PHY      M           NaN        15.306

# %%
columns_to_keep = ['Student No', 'Name', 'Major', 'Gender',
                   'Test 1 (30%)', 'Test 2 (20%)']

df_class = df_class[columns_to_keep]

# %%
new_column_info = {'Student No': 'MATRIC_NO',
                   'Test 1 (30%)': 'Test 1',
                   'Test 2 (20%)': 'Test 2'}

df_class.rename(columns=new_column_info, inplace=True)

# %%
df_class.head()
# Out:
#    MATRIC_NO             Name Major Gender  Test 1  Test 2
# 0  A3028967J   Braiden Henson   PHY      M  20.205   18.96
# 1  A1282849W     Gustavo Vang   CHM      F  13.470   17.44
# 2  A5408925A  Ronin Christian   PHY      M  18.366   15.56
# 3  A6973859L    Owen Anderson    LS      F  18.366   16.36
# 4  A5410124H       Kyla Young   PHY      M  15.306     NaN

# %%
df_class['Major'].unique()
# Out:
# array(['PHY', 'CHM', 'LS', 'CBIO'], dtype=object)

# %%
df_class['Gender'].unique()
# Out:
# array(['M', 'F', 'NB'], dtype=object)

# %%
replace_info = {
    'PHY': 'Physics',
    'CHM': 'Chemistry',
    'LS': 'Life Sciences',
    'CBIO': 'Comp. Biology',
    'F': 'Female',
    'M': 'Male',
    'NB': 'Non-binary'
}

df_class.replace(to_replace=replace_info, inplace=True)

# %%
def clean(text):
    try:
        return text.replace("'", "")
    except AttributeError:
        # This will handle the NaN of the missing data
        return text

df_class['Test 2'] = df_class['Test 2'].apply(clean)

# %%
df_class.head()
# Out:
#    MATRIC_NO             Name          Major  Gender  Test 1  Test 2
# 0  A3028967J   Braiden Henson        Physics    Male  20.205   18.96
# 1  A1282849W     Gustavo Vang      Chemistry  Female  13.470   17.44
# 2  A5408925A  Ronin Christian        Physics    Male  18.366   15.56
# 3  A6973859L    Owen Anderson  Life Sciences  Female  18.366   16.36
# 4  A5410124H       Kyla Young        Physics    Male  15.306     NaN

# %%
df_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MATRIC_NO  35 non-null     object
#  1   Name       35 non-null     object
#  2   Major      35 non-null     object
#  3   Gender     35 non-null     object
#  4   Test 1     33 non-null     float64
#  5   Test 2     32 non-null     float64
# dtypes: float64(2), object(4)
# memory usage: 1.8+ KB

# %%
new_type_info = {'Major': 'category',
                 'Gender': 'category',
                 'Test 2': 'float'}

# atype does NOT have an inplace option
df_class = df_class.astype(new_type_info)

# %%
df_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MATRIC_NO  35 non-null     object
#  1   Name       35 non-null     object
#  2   Major      35 non-null     category
#  3   Gender     35 non-null     category
#  4   Test 1     33 non-null     float64
#  5   Test 2     32 non-null     float64
# dtypes: category(2), float64(2), object(2)
# memory usage: 1.6+ KB

# %%
df_class["Total"] = df_class["Test 1"] + df_class["Test 2"]

# %%
df_class.to_excel('finalised_scores.xlsx', index=False)

# %%
df_class.head()
# Out:
#    MATRIC_NO             Name          Major  Gender  Test 1  Test 2   Total
# 0  A3028967J   Braiden Henson        Physics    Male  20.205   18.96  39.165
# 1  A1282849W     Gustavo Vang      Chemistry  Female  13.470   17.44  30.910
# 2  A5408925A  Ronin Christian        Physics    Male  18.366   15.56  33.926
# 3  A6973859L    Owen Anderson  Life Sciences  Female  18.366   16.36  34.726
# 4  A5410124H       Kyla Young        Physics    Male  15.306     NaN     NaN

# %%
df_class.iloc[10:13, 2:4]
# Out:
#             Major  Gender
# 10  Life Sciences  Female
# 11  Life Sciences    Male
# 12        Physics    Male

# %%
df_class.loc[["A7067766E", "A5569996J", "A3202548I"], ["Major", "Gender"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df_class.loc[["A7067766E", "A5569996J", "A3202548I"], ["Major", "Gender"]]
#
# File ~\miniconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\miniconda3\Lib\site-packages\pandas\core\indexing.py:1375, in _LocIndexer._getitem_tuple(self, tup)
#    1373 # ugly hack for GH #836
#    1374 if self._multi_take_opportunity(tup):
# -> 1375     return self._multi_take(tup)
#    1377 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
print(df_class.index)
# Out:
# RangeIndex(start=0, stop=35, step=1)

# %%
df_class.set_index('MATRIC_NO', inplace=True)

# %%
df_class.loc[["A7067766E", "A5569996J", "A3202548I"], ["Major", "Gender"]]
# Out:
#                    Major  Gender
# MATRIC_NO
# A7067766E  Life Sciences  Female
# A5569996J  Life Sciences    Male
# A3202548I        Physics    Male

# %%
df_class["Major"] == "Chemistry"
# Out:
# MATRIC_NO
# A3028967J    False
# A1282849W     True
# A5408925A    False
# A6973859L    False
# A5410124H    False
# A9568373Q    False
# A6824244G    False
# A9194090U    False
# A4828364M    False
# A4607700C    False
# A7067766E    False
# A5569996J    False
# A3202548I    False
# A6131593U    False
# A7653832E     True
# A9462811I    False
# A1218599T     True
# A7210476B    False
# A1512479K     True
# A7986368Y     True
# A2727061A    False
# A2999472W     True
# A7116486E    False
# A6931452S    False
# A9649096H    False
# A1643380L    False
# A6787293E    False
# A5975988J    False
# A3699958T     True
# A1956366U    False
# A1468689D     True
# A3217320C    False
# A6867791C    False
# A4080490P    False
# A7667457P    False
# Name: Major, dtype: bool

# %%
df_class.loc[df_class["Major"] == "Chemistry"]
# Out:
#                         Name      Major  Gender  Test 1  Test 2   Total
# MATRIC_NO
# A1282849W       Gustavo Vang  Chemistry  Female  13.470  17.440  30.910
# A7653832E       Quentin Kemp  Chemistry  Female     NaN  15.720     NaN
# A1218599T    Camden Williams  Chemistry  Female  22.653  17.648  40.301
# A1512479K   Solomon Fletcher  Chemistry  Female  18.981  15.000  33.981
# A7986368Y  Riley Christensen  Chemistry  Female  15.306  16.016  31.322
# A2999472W     Skylar Hensley  Chemistry    Male  23.877  17.648  41.525
# A3699958T        Norah Miles  Chemistry    Male     NaN     NaN     NaN
# A1468689D     Isabela Stokes  Chemistry    Male  18.366  16.800  35.166

# %%
df_class.loc[~(df_class["Major"] == "Life Sciences")]
# Out:
#                          Name          Major      Gender  Test 1  Test 2  \
# MATRIC_NO
# A3028967J      Braiden Henson        Physics        Male  20.205  18.960
# A1282849W        Gustavo Vang      Chemistry      Female  13.470  17.440
# A5408925A     Ronin Christian        Physics        Male  18.366  15.560
# A5410124H          Kyla Young        Physics        Male  15.306     NaN
# A9568373Q        Wyatt Oliver        Physics        Male  12.246  14.088
# A3202548I         Jaxon Chung        Physics        Male  14.082  16.680
# A7653832E        Quentin Kemp      Chemistry      Female     NaN  15.720
# A9462811I            Leo Mayo        Physics      Female  20.817  14.680
# A1218599T     Camden Williams      Chemistry      Female  22.653  17.648
# A7210476B      Sidney Wiggins        Physics  Non-binary  19.593  14.680
# A1512479K    Solomon Fletcher      Chemistry      Female  18.981  15.000
# A7986368Y   Riley Christensen      Chemistry      Female  15.306  16.016
# ...

# %%
# Create mask
mask = (df_class["Major"] == "Chemistry") & (df_class["Gender"] == 'Female')

# Using mask
df_class.loc[mask, ["Name", "Major", "Gender"]]
# Out:
#                         Name      Major  Gender
# MATRIC_NO
# A1282849W       Gustavo Vang  Chemistry  Female
# A7653832E       Quentin Kemp  Chemistry  Female
# A1218599T    Camden Williams  Chemistry  Female
# A1512479K   Solomon Fletcher  Chemistry  Female
# A7986368Y  Riley Christensen  Chemistry  Female

# %%
mask = df_class["Test 1"] < 15
df_class.loc[mask, ["Name", "Major", "Test 1"]]
# Out:
#                        Name      Major  Test 1
# MATRIC_NO
# A1282849W      Gustavo Vang  Chemistry  13.470
# A9568373Q      Wyatt Oliver    Physics  12.246
# A3202548I       Jaxon Chung    Physics  14.082
# A2727061A      Malik Becker    Physics  12.858
# A1643380L  Carolina Mcmahon    Physics  12.858

# %%
df_class.groupby(by=["Major"]).mean(numeric_only=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12972\600927947.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_class.groupby(by=["Major"]).mean(numeric_only=True)
#                 Test 1     Test 2      Total
# Major
# Chemistry      18.7755  16.610286  35.534167
# Comp. Biology  16.5300  10.280000  26.810000
# Life Sciences  19.2420  14.690286  33.932286
# Physics        17.7555  16.076800  34.567000

# %%
df_class.groupby(by=["Major"])[['Test 1', 'Test 2', 'Total']].mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12972\4139776104.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_class.groupby(by=["Major"])[['Test 1', 'Test 2', 'Total']].mean()
#                 Test 1     Test 2      Total
# Major
# Chemistry      18.7755  16.610286  35.534167
# Comp. Biology  16.5300  10.280000  26.810000
# Life Sciences  19.2420  14.690286  33.932286
# Physics        17.7555  16.076800  34.567000

# %%
df_class.groupby(by=["Major", "Gender"])[['Test 1', 'Test 2', 'Total']].mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12972\2433111876.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_class.groupby(by=["Major", "Gender"])[['Test 1', 'Test 2', 'Total']].mean()
#                              Test 1     Test 2      Total
# Major         Gender
# Chemistry     Female      17.602500  16.364800  34.128500
#               Male        21.121500  17.224000  38.345500
#               Non-binary        NaN        NaN        NaN
# Comp. Biology Female      16.530000  10.280000  26.810000
#               Male              NaN        NaN        NaN
#               Non-binary        NaN        NaN        NaN
# Life Sciences Female      19.285875  14.801000  34.086875
#               Male        20.357250  15.644000  36.001250
# ...

# %%
df_class.groupby(by=["Major", "Gender"], as_index=False)[['Test 1', 'Test 2', 'Total']].mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12972\4154723149.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_class.groupby(by=["Major", "Gender"], as_index=False)[['Test 1', 'Test 2', 'Total']].mean()
#             Major      Gender     Test 1     Test 2      Total
# 0       Chemistry      Female  17.602500  16.364800  34.128500
# 1       Chemistry        Male  21.121500  17.224000  38.345500
# 2       Chemistry  Non-binary        NaN        NaN        NaN
# 3   Comp. Biology      Female  16.530000  10.280000  26.810000
# 4   Comp. Biology        Male        NaN        NaN        NaN
# 5   Comp. Biology  Non-binary        NaN        NaN        NaN
# 6   Life Sciences      Female  19.285875  14.801000  34.086875
# 7   Life Sciences        Male  20.357250  15.644000  36.001250
# ...

# %%
df_class.groupby(by=["Major", "Gender"])["Test 1"].mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12972\1608057694.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_class.groupby(by=["Major", "Gender"])["Test 1"].mean()
# Major          Gender
# Chemistry      Female        17.602500
#                Male          21.121500
#                Non-binary          NaN
# Comp. Biology  Female        16.530000
#                Male                NaN
#                Non-binary          NaN
# Life Sciences  Female        19.285875
#                Male          20.357250
#                Non-binary    16.836000
# Physics        Female        20.817000
#                Male          16.871000
#                Non-binary    20.205000
# Name: Test 1, dtype: float64

# %%
df_class.groupby(by=["Major", "Gender"])[['Test 1', 'Test 2', 'Total']].agg([np.mean, np.std]).round(2)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12972\2420357119.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_class.groupby(by=["Major", "Gender"])[['Test 1', 'Test 2', 'Total']].agg([np.mean, np.std]).round(2)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12972\2420357119.py:1: FutureWarning: The provided callable <function mean at 0x000002B423AEF560> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_class.groupby(by=["Major", "Gender"])[['Test 1', 'Test 2', 'Total']].agg([np.mean, np.std]).round(2)
# ...

# %%
mask = df_class['Gender'] == 'Female'
df_class[mask].groupby(by=['Major']).mean(numeric_only=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12972\4158641400.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_class[mask].groupby(by=['Major']).mean(numeric_only=True)
#                   Test 1   Test 2      Total
# Major
# Chemistry      17.602500  16.3648  34.128500
# Comp. Biology  16.530000  10.2800  26.810000
# Life Sciences  19.285875  14.8010  34.086875
# Physics        20.817000  14.6800  35.497000

# %%
df_class.groupby(by=["Gender", "Major"]).mean(numeric_only=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12972\987950824.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_class.groupby(by=["Gender", "Major"]).mean(numeric_only=True)
#                              Test 1     Test 2      Total
# Gender     Major
# Female     Chemistry      17.602500  16.364800  34.128500
#            Comp. Biology  16.530000  10.280000  26.810000
#            Life Sciences  19.285875  14.801000  34.086875
#            Physics        20.817000  14.680000  35.497000
# Male       Chemistry      21.121500  17.224000  38.345500
#            Comp. Biology        NaN        NaN        NaN
#            Life Sciences  20.357250  15.644000  36.001250
#            Physics        16.871000  16.498286  34.166143
# Non-binary Chemistry            NaN        NaN        NaN
# ...

# %%
pip install numpy scipy matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import scipy.io.wavfile as wav
import matplotlib.pyplot as plt

# Step 1: Load the WAV file
def load_wav(filename):
    rate, data = wav.read(filename)
    return rate, data

# Step 2: Perform FFT to convert time-domain to frequency-domain
def perform_fft(data, rate):
    fft_data = np.fft.fft(data)
    freqs = np.fft.fftfreq(len(fft_data), 1 / rate)
    
    # Only keep the positive frequencies (real part)
    positive_freqs = freqs[:len(freqs) // 2]
    positive_fft_data = np.abs(fft_data[:len(fft_data) // 2])
    
    return positive_freqs, positive_fft_data

# Step 3: Find the maximum peak frequency
def find_max_peak(freqs, fft_data):
    # Find the index of the maximum value in the FFT data
    max_index = np.argmax(fft_data)
    # Get the corresponding frequency for the max value
    max_freq = freqs[max_index]
    return max_freq

# Step 4: Main code to load and analyze one WAV file
def analyze_wav(filename):
    rate, data = load_wav(filename)
    print(f"Loaded {filename} with sample rate {rate} Hz")

    # If the audio is stereo, take just one channel (mono)
    if len(data.shape) > 1:
        data = data[:, 0]

    # Perform FFT
    freqs, fft_data = perform_fft(data, rate)

    # Find the maximum peak frequency
    max_freq = find_max_peak(freqs, fft_data)

    # Output the maximum peak frequency
    print(f"Maximum peak frequency: {max_freq} Hz")

    # Step 5: Plot the FFT data
    plt.figure(figsize=(10, 6))
    plt.plot(freqs, fft_data)
    plt.title("FFT of Audio Signal")
    plt.xlabel("Frequency (Hz)")
    plt.ylabel("Amplitude")
    plt.xlim(0, 2000)  # You can adjust this to focus on the desired frequency range
    plt.grid(True)
    plt.show()

# Example usage: Replace 'your_file.wav' with the path to your actual file
analyze_wav("Violin_quaver_240_beat.wav")
# Out:
# Loaded Violin_quaver_240_beat.wav with sample rate 44100 Hz
# Maximum peak frequency: 261.0 Hz

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile as wav
import os

# Specify the path to your audio file
sound_data = "./sound_data/Violin A-violin.wav"  # Assuming the file is in the 'sound_data' folder in the current directory

# Check if the file exists
if not os.path.exists(sound_data):
    print(f"Error, {sound_data} doesn't exist")
else:
    print("File exists! Proceeding with analysis...")

    # Read the audio file
    sample_rate, data = wav.read(sound_data)

    # If stereo, take only one channel (usually the left one)
    if len(data.shape) > 1:
        data = data[:, 0]

    # Perform FFT
    fft_data = np.fft.fft(data)
    amplitude = np.abs(fft_data)  # Amplitude of FFT
    frequencies = np.fft.fftfreq(len(data), d=1/sample_rate)  # Frequency values corresponding to FFT bins

    # Keep only positive frequencies (real part)
    positive_freq = frequencies[:len(frequencies)//2]
    positive_ampl = amplitude[:len(amplitude)//2]

    # Find the fundamental frequency (the peak amplitude)
    fundamental_index = np.argmax(positive_ampl)
    fundamental_freq = positive_freq[fundamental_index]

    print(f"Fundamental Frequency: {fundamental_freq} Hz")

    # Normalize frequency (shifting everything so fundamental aligns with 440Hz)
    freq_shift = fundamental_freq - 440  # Shift so fundamental aligns with 440 Hz (A#)
    norm_freqs = positive_freq - freq_shift

    # Normalize amplitude (normalize by the amplitude at 440Hz)
    index_440Hz = np.argmin(np.abs(norm_freqs - 440))  # Find the index closest to 440Hz
    ampl_at_440Hz = positive_ampl[index_440Hz]
    norm_ampl = positive_ampl / ampl_at_440Hz  # Normalize amplitude

    # Plot the normalized spectrum
    plt.figure(figsize=(10, 5))
    plt.plot(norm_freqs, norm_ampl, label="Normalized Spectrum")
    plt.axvline(440, color='r', linestyle='--', label="440Hz Reference")
    plt.xlabel("Frequency (Hz)")
    plt.ylabel("Normalized Amplitude")
    plt.title("Normalized FFT Spectrum")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# File exists! Proceeding with analysis...
# Fundamental Frequency: 441.03053435114504 Hz
