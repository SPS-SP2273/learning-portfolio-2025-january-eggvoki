# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %%
# Exercise 1 (Learning to interrupt)
while True:
    print('*', end='')
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Exercise 1 (Learning to interrupt)
#       2 while True:
# ----> 3     print('*', end='')
#
# File ~\miniconda3\Lib\site-packages\ipykernel\iostream.py:681, in OutStream.write(self, string)
#     678     msg = "I/O operation on closed file"
#     679     raise ValueError(msg)
# --> 681 is_child = not self._is_master_process()
#     682 # only touch the buffer in the IO thread to avoid races
#     683 with self._buffer_lock:
#
# File ~\miniconda3\Lib\site-packages\ipykernel\iostream.py:550, in OutStream._is_master_process(self)
#     547     self.watch_fd_thread.daemon = True
#     548     self.watch_fd_thread.start()
# --> 550 def _is_master_process(self):
#     551     return os.getpid() == self._master_pid
#     553 def set_parent(self, parent):
#
# KeyboardInterrupt:

# %% [markdown]
# Exercise 2 (Resetting & Restarting the Kernal)

# %%
print = 'PRINT'
print('Hello World')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 print = 'PRINT'
# ----> 2 print('Hello World')
#
# TypeError: 'str' object is not callable

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# Exercise 3 (Timing Stuff)

# %%
# %timeit squares = [i**2 for i in range(10)]
# Out:
# 1.32 μs ± 92.1 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
squares = [i**2 for i in range(10)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares = list()
for i in range(10):
    squares.append(i**2)
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# %%timeit 
squares = list()
for i in range(10):
    squares.append(i**2)
# Out:
# 1.71 μs ± 285 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# 1.32 is the mean time taken to run each loop while 92.1 is the standard deviation of it. There are 7 runs total and each run consist of 1 million loops.
#
# 1.71 is the mean time taken to run each loop while 285 is the standard deviation of it. There are 7 runs total and each run consist of 1 million loops.
#
# The first code is faster.
