# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Functions (Good)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Checks, balances, and contingencies

# %% [markdown]
# ## 1.1 assert

# %%
assert condition-to-check, message
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 assert condition-to-check, message
#
# NameError: name 'condition' is not defined

# %%
assert x>=0, 'x is becoming negative!'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 assert x>=0, 'x is becoming negative!'
#
# NameError: name 'x' is not defined

# %%
x=10
assert x>=0, 'x is becoming negative!'

# %%
x=-1
assert x>=0, 'x is becoming negative!'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 x=-1
# ----> 2 assert x>=0, 'x is becoming negative!'
#
# AssertionError: x is becoming negative!

# %% [markdown]
# ## 1.2 try-except

# %%
number=input('Give me a number and I will calculate its square.')
square=int(number)**2
print(f'The square of {number} is {square}!')
# Out:
# Give me a number and I will calculate its square. 2
# The square of 2 is 4!

# %%
try:
    number=input('Give me a number and I will calculate its square.')
    square=int(number)**2
    print(f'The square of {number} is {square}!')
except:
    print(f'Oh oh! I cannot square {number}!')
# Out:
# Give me a number and I will calculate its square. hahaha
# Oh oh! I cannot square hahaha!

# %% [markdown]
# ## 1.3 A simple suggestion

# %% [markdown]
# # 2 Some loose ends

# %% [markdown]
# ## 2.1 Positional, keyword and default arguments

# %%
def side_by_side(a,b,c=42):
    return f'{a:2d}|{b:2d}|{c:2d}'

# %% [markdown]
# ### Positional

# %%
side_by_side(1,2,3)
# Out:
# ' 1| 2| 3'

# %% [markdown]
# ### Keywords

# %%
side_by_side(c=3, b=1, a=2)
# Out:
# ' 2| 1| 3'

# %% [markdown]
# ### Default

# %%
side_by_side(1, b=2)
# Out:
# ' 1| 2|42'

# %%
side_by_side(1,2) # Two positional, 1 default
# Out:
# ' 1| 2|42'

# %%
side_by_side(1,2,3) # Three positional
# Out:
# ' 1| 2| 3'

# %%
side_by_side(a=1, b=2) # Three positional
# Out:
# ' 1| 2|42'

# %%
side_by_side(c=3, b=1, a=2) # Three keyword
# Out:
# ' 2| 1| 3'

# %%
side_by_side(1, c=3, b=2) # One positional, 2 keyword
# Out:
# ' 1| 2| 3'

# %%
side_by_side(1, b=2) # One positional, 1 keyword, 1 default
# Out:
# ' 1| 2|42'

# %%
# Keywords cannot be followed
# by positional arguments
side_by_side(a=2, 1) # Won't work.
# Out:
#   Cell In[30], line 3
#     side_by_side(a=2, 1) # Won't work.
#                        ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ## 2.2 Docstrings

# %%
def side_by_side(a, b, c=42):
    '''
    A test function to demonstrate how positional, keyword and default arguments work.
    '''
    return f'{a:2d}|{b:2d}|{c:2d}'

# %%
help(side_by_side)
# Out:
# Help on function side_by_side in module __main__:
#
# side_by_side(a, b, c=42)
#     A test function to demonstrate how positional, keyword and default arguments work.

# %% [markdown]
# ## 2.3 Function are first-class citizens

# %%
def my_function(angle, trig_function):
    return trig_function(angle)

# Let's use the function
import numpy as np
my_function(np.pi/2, np.sin)
# Out:
# np.float64(1.0)

# %%
my_function(np.pi/2, np.cos)
# Out:
# np.float64(6.123233995736766e-17)

# %%
my_function(np.pi/2, lambda x: np.cos)

# %% [markdown]
# ## 2.4 More about unpacking

# %%
def area_triangle(base, height):
    return(1/2*base*height)

# %%
area_triangle(4,5)
# Out:
# 10.0

# %%
base #local variable
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 base #local variable
#
# NameError: name 'base' is not defined

# %%
x=-1
assert x>=0, 'x must be positive'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[43], line 2
#       1 x=-1
# ----> 2 assert x>=0, 'x must be positive'
#
# AssertionError: x must be positive

# %%
for i in range(10):
    assert i<=5, 'i is too big'
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[44], line 2
#       1 for i in range(10):
# ----> 2     assert i<=5, 'i is too big'
#       3     print(i)
#
# AssertionError: i is too big

# %%
for i in range(10):
    try:
        print(1/i)
    except ZeroDivisionError:
        print('you divided by 0, idiot')
# Out:
# you divided by 0, idiot
# 1.0
# 0.5
# 0.3333333333333333
# 0.25
# 0.2
# 0.16666666666666666
# 0.14285714285714285
# 0.125
# 0.1111111111111111

# %%
    try:
        x=input('Tell me your age')
        x=int(x)
    
    except ValueError:
        print('Input a number, doIt!')
# Out:
# Tell me your age a
# Input a number, doIt!
# Tell me your age n
# Input a number, doIt!
# Tell me your age a
# Input a number, doIt!
# Tell me your age fdsaf
# Input a number, doIt!

# %%
def volume_cuboid(length,width,height=5):
    return(length*height*width)
volume_cuboid(5,6)
# Out:
# 150

# %%
found=False
while found==False:
    try:
        x=input('Tell me your age')
# Out:
#   Cell In[2], line 4
#     x=input('Tell me your age')
#                                ^
# SyntaxError: incomplete input

# %%
def calculator(value,func):
    '''This is something we created in SP2273 to calculate stuff.''' #Docstring
    return func(value)

# %%
help(calculator)
# Out:
# Help on function calculator in module __main__:
#
# calculator(value, func)
#     This is something we created in SP2273 to calculate stuff.

# %%
import numpy as np
calculator(0,np.sin)
# Out:
# np.float64(0.0)

# %%
x=np.array([0,0.1,0.2])
calculator(x,np.sin)==np.sin(x)
# Out:
# array([ True,  True,  True])

# %%
import matplotlib as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import matplotlib as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !conda install matplotlib -c conda-forge -y
# Out:
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Admin\miniconda3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |            2_gnu          48 KB  conda-forge
#     brotli-1.1.0               |       h2466b09_2          19 KB  conda-forge
#     brotli-bin-1.1.0           |       h2466b09_2          20 KB  conda-forge
#     ca-certificates-2025.1.31  |       h56e8100_0         155 KB  conda-forge
#     cairo-1.18.2               |       h5782bbf_1         1.4 MB  conda-forge
#     conda-25.1.1               |  py312h2e8e312_0         1.1 MB  conda-forge
#     contourpy-1.3.1            |  py312hd5eb7cc_0         211 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_1          13 KB  conda-forge
#     double-conversion-3.3.0    |       h63175ca_0          69 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.15.0          |       h765892d_1         188 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     fonttools-4.55.8           |  py312h31fea79_0         2.3 MB  conda-forge
#     freetype-2.12.1            |       hdaf720e_2         498 KB  conda-forge
#     graphite2-1.3.13           |    h63175ca_1003          93 KB  conda-forge
#     harfbuzz-10.2.0            |       h885c0d4_0         1.1 MB  conda-forge
#     icu-75.1                   |       he0c23c2_0        13.9 MB  conda-forge
#     kiwisolver-1.4.8           |  py312hc790b64_0          70 KB  conda-forge
#     lcms2-2.16                 |       h67d730c_0         496 KB  conda-forge
#     lerc-4.0.0                 |       h63175ca_0         190 KB  conda-forge
#     libarchive-3.7.7           |       h979ed78_3         1.0 MB  conda-forge
#     libbrotlicommon-1.1.0      |       h2466b09_2          69 KB  conda-forge
#     libbrotlidec-1.1.0         |       h2466b09_2          32 KB  conda-forge
#     libbrotlienc-1.1.0         |       h2466b09_2         240 KB  conda-forge
#     libclang13-19.1.7          |default_ha5278ca_1        25.5 MB  conda-forge
#     libcurl-8.11.1             |       h88aaa65_0         341 KB  conda-forge
#     libdeflate-1.23            |       h9062f6e_0         152 KB  conda-forge
#     libgcc-14.2.0              |       h1383e82_1         651 KB  conda-forge
#     libglib-2.82.2             |       h7025463_1         3.6 MB  conda-forge
#     libgomp-14.2.0             |       h1383e82_1         512 KB  conda-forge
#     libiconv-1.17              |       hcfcfb64_2         621 KB  conda-forge
#     libintl-0.22.5             |       h5728263_3          93 KB  conda-forge
#     libjpeg-turbo-3.0.0        |       hcfcfb64_1         804 KB  conda-forge
#     liblzma-5.6.4              |       h2466b09_0         102 KB  conda-forge
#     libmamba-1.5.11            |       h99b1521_1         3.9 MB
#     libmambapy-1.5.11          |  py312hcd6fe79_1         278 KB
#     libpng-1.6.46              |       had7236b_0         348 KB  conda-forge
#     libsolv-0.7.30             |       hbb528cf_0         419 KB  conda-forge
#     libssh2-1.11.1             |       he619c9f_0         285 KB  conda-forge
#     libtiff-4.7.0              |       h797046b_3         956 KB  conda-forge
#     libwebp-base-1.5.0         |       h3b0e114_0         267 KB  conda-forge
#     libxcb-1.17.0              |       h0e4246c_0         1.2 MB  conda-forge
#     libxml2-2.13.5             |       he286e8c_1         1.5 MB  conda-forge
#     libxslt-1.1.39             |       h3df6e99_0         409 KB  conda-forge
#     libzlib-1.3.1              |       h2466b09_2          54 KB  conda-forge
#     lz4-c-1.10.0               |       h2466b09_1         137 KB  conda-forge
#     lzo-2.10                   |    hcfcfb64_1001         139 KB  conda-forge
#     matplotlib-3.10.0          |  py312h2e8e312_0          17 KB  conda-forge
#     matplotlib-base-3.10.0     |  py312h90004f6_0         7.6 MB  conda-forge
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     openjpeg-2.5.3             |       h4d64b90_0         235 KB  conda-forge
#     pcre2-10.44                |       h3d7b363_2         802 KB  conda-forge
#     pillow-11.1.0              |  py312h078707f_0        39.9 MB  conda-forge
#     pixman-0.44.2              |       had0cd8c_0         445 KB  conda-forge
#     pthread-stubs-0.4          |    h0e40799_1002           9 KB  conda-forge
#     pyparsing-3.2.1            |     pyhd8ed1ab_0          91 KB  conda-forge
#     pyside6-6.8.1              |  py312h2ee7485_0         9.3 MB  conda-forge
#     qhull-2020.2               |       hc790b64_5         1.3 MB  conda-forge
#     qt6-main-6.8.1             |       h1259614_2        87.8 MB  conda-forge
#     tk-8.6.13                  |       h5226925_1         3.3 MB  conda-forge
#     unicodedata2-16.0.0        |  py312h4389bb4_0         392 KB  conda-forge
#     xorg-libxau-1.0.12         |       h0e40799_0         105 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       h0e40799_0          68 KB  conda-forge
#     zlib-1.3.1                 |       h2466b09_2         105 KB  conda-forge
#     zstd-1.5.6                 |       h0ea2cb4_0         341 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       219.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   _openmp_mutex      conda-forge/win-64::_openmp_mutex-4.5-2_gnu
#   brotli             conda-forge/win-64::brotli-1.1.0-h2466b09_2
#   brotli-bin         conda-forge/win-64::brotli-bin-1.1.0-h2466b09_2
#   cairo              conda-forge/win-64::cairo-1.18.2-h5782bbf_1
#   contourpy          conda-forge/win-64::contourpy-1.3.1-py312hd5eb7cc_0
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_1
#   double-conversion  conda-forge/win-64::double-conversion-3.3.0-h63175ca_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/win-64::fontconfig-2.15.0-h765892d_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   fonttools          conda-forge/win-64::fonttools-4.55.8-py312h31fea79_0
#   freetype           conda-forge/win-64::freetype-2.12.1-hdaf720e_2
#   graphite2          conda-forge/win-64::graphite2-1.3.13-h63175ca_1003
#   harfbuzz           conda-forge/win-64::harfbuzz-10.2.0-h885c0d4_0
#   icu                conda-forge/win-64::icu-75.1-he0c23c2_0
#   kiwisolver         conda-forge/win-64::kiwisolver-1.4.8-py312hc790b64_0
#   lcms2              conda-forge/win-64::lcms2-2.16-h67d730c_0
#   lerc               conda-forge/win-64::lerc-4.0.0-h63175ca_0
#   libbrotlicommon    conda-forge/win-64::libbrotlicommon-1.1.0-h2466b09_2
#   libbrotlidec       conda-forge/win-64::libbrotlidec-1.1.0-h2466b09_2
#   libbrotlienc       conda-forge/win-64::libbrotlienc-1.1.0-h2466b09_2
#   libclang13         conda-forge/win-64::libclang13-19.1.7-default_ha5278ca_1
#   libdeflate         conda-forge/win-64::libdeflate-1.23-h9062f6e_0
#   libgcc             conda-forge/win-64::libgcc-14.2.0-h1383e82_1
#   libglib            conda-forge/win-64::libglib-2.82.2-h7025463_1
#   libgomp            conda-forge/win-64::libgomp-14.2.0-h1383e82_1
#   libintl            conda-forge/win-64::libintl-0.22.5-h5728263_3
#   libjpeg-turbo      conda-forge/win-64::libjpeg-turbo-3.0.0-hcfcfb64_1
#   liblzma            conda-forge/win-64::liblzma-5.6.4-h2466b09_0
#   libpng             conda-forge/win-64::libpng-1.6.46-had7236b_0
#   libtiff            conda-forge/win-64::libtiff-4.7.0-h797046b_3
#   libwebp-base       conda-forge/win-64::libwebp-base-1.5.0-h3b0e114_0
#   libxcb             conda-forge/win-64::libxcb-1.17.0-h0e4246c_0
#   libxslt            conda-forge/win-64::libxslt-1.1.39-h3df6e99_0
#   lzo                conda-forge/win-64::lzo-2.10-hcfcfb64_1001
#   matplotlib         conda-forge/win-64::matplotlib-3.10.0-py312h2e8e312_0
#   matplotlib-base    conda-forge/win-64::matplotlib-base-3.10.0-py312h90004f6_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   openjpeg           conda-forge/win-64::openjpeg-2.5.3-h4d64b90_0
#   pillow             conda-forge/win-64::pillow-11.1.0-py312h078707f_0
#   pixman             conda-forge/win-64::pixman-0.44.2-had0cd8c_0
#   pthread-stubs      conda-forge/win-64::pthread-stubs-0.4-h0e40799_1002
#   pyparsing          conda-forge/noarch::pyparsing-3.2.1-pyhd8ed1ab_0
#   pyside6            conda-forge/win-64::pyside6-6.8.1-py312h2ee7485_0
#   qhull              conda-forge/win-64::qhull-2020.2-hc790b64_5
#   qt6-main           conda-forge/win-64::qt6-main-6.8.1-h1259614_2
#   unicodedata2       conda-forge/win-64::unicodedata2-16.0.0-py312h4389bb4_0
#   xorg-libxau        conda-forge/win-64::xorg-libxau-1.0.12-h0e40799_0
#   xorg-libxdmcp      conda-forge/win-64::xorg-libxdmcp-1.1.5-h0e40799_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2024.12.31~ --> conda-forge::ca-certificates-2025.1.31-h56e8100_0
#   conda                             24.11.3-py312h2e8e312_0 --> 25.1.1-py312h2e8e312_0
#   libarchive         pkgs/main::libarchive-3.7.4-h9243413_0 --> conda-forge::libarchive-3.7.7-h979ed78_3
#   libcurl               pkgs/main::libcurl-8.9.1-h0416ee5_0 --> conda-forge::libcurl-8.11.1-h88aaa65_0
#   libiconv              pkgs/main::libiconv-1.16-h2bbff1b_3 --> conda-forge::libiconv-1.17-hcfcfb64_2
#   libmamba                                1.5.11-h99b1521_0 --> 1.5.11-h99b1521_1
#   libmambapy                         1.5.11-py312hcd6fe79_0 --> 1.5.11-py312hcd6fe79_1
#   libsolv              pkgs/main::libsolv-0.7.24-h23ce68f_1 --> conda-forge::libsolv-0.7.30-hbb528cf_0
#   libxml2              pkgs/main::libxml2-2.13.5-h24da03e_0 --> conda-forge::libxml2-2.13.5-he286e8c_1
#   libzlib                                 1.2.13-h2466b09_6 --> 1.3.1-h2466b09_2
#   lz4-c                   pkgs/main::lz4-c-1.9.4-h2bbff1b_1 --> conda-forge::lz4-c-1.10.0-h2466b09_1
#   pcre2                   pkgs/main::pcre2-10.42-h0ff8eda_1 --> conda-forge::pcre2-10.44-h3d7b363_2
#   zlib                                    1.2.13-h2466b09_6 --> 1.3.1-h2466b09_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   libssh2              pkgs/main::libssh2-1.11.1-h2addb87_0 --> conda-forge::libssh2-1.11.1-he619c9f_0
#   tk                        pkgs/main::tk-8.6.14-h0416ee5_0 --> conda-forge::tk-8.6.13-h5226925_1
#   zstd                     pkgs/main::zstd-1.5.6-h8880b57_0 --> conda-forge::zstd-1.5.6-h0ea2cb4_0
#
#
#
# Downloading and Extracting Packages: ...working...
# qt6-main-6.8.1       | 87.8 MB   |            |   0%
#
# pillow-11.1.0        | 39.9 MB   |            |   0%
#
#
# libclang13-19.1.7    | 25.5 MB   |            |   0%
#
#
#
# icu-75.1             | 13.9 MB   |            |   0%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    |            |   0%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    |            |   0%
#
#
#
#
#
#
# libmamba-1.5.11      | 3.9 MB    |            |   0%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    |            |   0%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    |            |   0%
#
#
#
#
#
#
#
#
#
# fonttools-4.55.8     | 2.3 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 1.5 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.2         | 1.4 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.3 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 1.2 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-25.1.1         | 1.1 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.2.0      | 1.1 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 1.0 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 956 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    |            |   0%
#
#
#
# icu-75.1             | 13.9 MB   |            |   0%
#
#
# libclang13-19.1.7    | 25.5 MB   |            |   0%
#
# pillow-11.1.0        | 39.9 MB   |            |   0%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | 5          |   5%
# qt6-main-6.8.1       | 87.8 MB   |            |   0%
#
#
#
# icu-75.1             | 13.9 MB   | 2          |   2%
#
# pillow-11.1.0        | 39.9 MB   |            |   1%
#
#
# libclang13-19.1.7    | 25.5 MB   | 1          |   1%
#
#
#
# icu-75.1             | 13.9 MB   | 4          |   4%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | 8          |   8%
#
#
# libclang13-19.1.7    | 25.5 MB   | 3          |   3%
# qt6-main-6.8.1       | 87.8 MB   |            |   0%
#
# pillow-11.1.0        | 39.9 MB   | 1          |   1%
#
#
#
# icu-75.1             | 13.9 MB   | 7          |   8%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | #          |  11%
#
# pillow-11.1.0        | 39.9 MB   | 2          |   2%
# qt6-main-6.8.1       | 87.8 MB   |            |   1%
#
#
# libclang13-19.1.7    | 25.5 MB   | 4          |   4%
#
#
#
# icu-75.1             | 13.9 MB   | 9          |  10%
# qt6-main-6.8.1       | 87.8 MB   | 1          |   1%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | #3         |  13%
#
# pillow-11.1.0        | 39.9 MB   | 2          |   3%
#
#
# libclang13-19.1.7    | 25.5 MB   | 5          |   5%
#
#
#
# icu-75.1             | 13.9 MB   | #1         |  12%
# qt6-main-6.8.1       | 87.8 MB   | 1          |   2%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | #5         |  15%
#
#
# libclang13-19.1.7    | 25.5 MB   | 6          |   6%
#
# pillow-11.1.0        | 39.9 MB   | 3          |   3%
# qt6-main-6.8.1       | 87.8 MB   | 1          |   2%
#
#
#
# icu-75.1             | 13.9 MB   | #3         |  14%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | #7         |  18%
#
# pillow-11.1.0        | 39.9 MB   | 3          |   4%
#
#
# libclang13-19.1.7    | 25.5 MB   | 7          |   8%
#
#
#
# icu-75.1             | 13.9 MB   | #6         |  16%
#
# pillow-11.1.0        | 39.9 MB   | 4          |   4%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | #9         |  20%
#
#
# libclang13-19.1.7    | 25.5 MB   | 9          |  10%
# qt6-main-6.8.1       | 87.8 MB   | 2          |   2%
#
#
#
# icu-75.1             | 13.9 MB   | #8         |  19%
#
# pillow-11.1.0        | 39.9 MB   | 4          |   5%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ##1        |  22%
#
#
# libclang13-19.1.7    | 25.5 MB   | #1         |  11%
# qt6-main-6.8.1       | 87.8 MB   | 2          |   3%
#
#
#
# icu-75.1             | 13.9 MB   | ##         |  21%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ##3        |  24%
#
# pillow-11.1.0        | 39.9 MB   | 5          |   5%
# qt6-main-6.8.1       | 87.8 MB   | 2          |   3%
#
#
# libclang13-19.1.7    | 25.5 MB   | #2         |  12%
#
#
#
# icu-75.1             | 13.9 MB   | ##2        |  23%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ##5        |  26%
# qt6-main-6.8.1       | 87.8 MB   | 3          |   3%
#
# pillow-11.1.0        | 39.9 MB   | 5          |   6%
#
#
# libclang13-19.1.7    | 25.5 MB   | #3         |  13%
#
#
#
# icu-75.1             | 13.9 MB   | ##4        |  24%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ##8        |  29%
# qt6-main-6.8.1       | 87.8 MB   | 3          |   4%
#
#
# libclang13-19.1.7    | 25.5 MB   | #4         |  15%
#
# pillow-11.1.0        | 39.9 MB   | 6          |   6%
#
#
#
# icu-75.1             | 13.9 MB   | ##6        |  26%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ###1       |  31%
# qt6-main-6.8.1       | 87.8 MB   | 4          |   4%
#
# pillow-11.1.0        | 39.9 MB   | 6          |   7%
#
#
# libclang13-19.1.7    | 25.5 MB   | #5         |  16%
#
#
#
# icu-75.1             | 13.9 MB   | ##8        |  28%
# qt6-main-6.8.1       | 87.8 MB   | 4          |   4%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ###3       |  33%
#
# pillow-11.1.0        | 39.9 MB   | 7          |   7%
#
#
# libclang13-19.1.7    | 25.5 MB   | #6         |  17%
#
#
#
# icu-75.1             | 13.9 MB   | ##9        |  30%
# qt6-main-6.8.1       | 87.8 MB   | 4          |   5%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ###5       |  36%
#
# pillow-11.1.0        | 39.9 MB   | 7          |   8%
#
#
# libclang13-19.1.7    | 25.5 MB   | #8         |  18%
#
#
#
# icu-75.1             | 13.9 MB   | ###1       |  32%
# qt6-main-6.8.1       | 87.8 MB   | 5          |   5%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ###7       |  38%
#
# pillow-11.1.0        | 39.9 MB   | 8          |   8%
#
#
# libclang13-19.1.7    | 25.5 MB   | #8         |  19%
#
#
#
# icu-75.1             | 13.9 MB   | ###3       |  33%
# qt6-main-6.8.1       | 87.8 MB   | 5          |   6%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ####       |  40%
#
# pillow-11.1.0        | 39.9 MB   | 8          |   8%
#
#
# libclang13-19.1.7    | 25.5 MB   | #9         |  20%
#
#
#
# icu-75.1             | 13.9 MB   | ###5       |  35%
# qt6-main-6.8.1       | 87.8 MB   | 6          |   6%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ####2      |  42%
#
# pillow-11.1.0        | 39.9 MB   | 8          |   9%
#
#
# libclang13-19.1.7    | 25.5 MB   | ##         |  21%
#
#
#
# icu-75.1             | 13.9 MB   | ###7       |  37%
# qt6-main-6.8.1       | 87.8 MB   | 6          |   6%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ####4      |  44%
#
#
# libclang13-19.1.7    | 25.5 MB   | ##1        |  22%
#
#
#
# icu-75.1             | 13.9 MB   | ###8       |  39%
#
# pillow-11.1.0        | 39.9 MB   | 9          |   9%
# qt6-main-6.8.1       | 87.8 MB   | 6          |   7%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ####6      |  47%
#
#
# libclang13-19.1.7    | 25.5 MB   | ##2        |  23%
#
#
#
# icu-75.1             | 13.9 MB   | ####       |  41%
#
# pillow-11.1.0        | 39.9 MB   | 9          |  10%
# qt6-main-6.8.1       | 87.8 MB   | 7          |   7%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ####8      |  49%
#
#
# libclang13-19.1.7    | 25.5 MB   | ##3        |  24%
#
#
#
# icu-75.1             | 13.9 MB   | ####2      |  43%
#
# pillow-11.1.0        | 39.9 MB   | #          |  10%
# qt6-main-6.8.1       | 87.8 MB   | 7          |   8%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | #####      |  51%
#
#
# libclang13-19.1.7    | 25.5 MB   | ##4        |  25%
#
#
#
# icu-75.1             | 13.9 MB   | ####4      |  44%
#
# pillow-11.1.0        | 39.9 MB   | #          |  11%
# qt6-main-6.8.1       | 87.8 MB   | 7          |   8%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | #####3     |  53%
#
#
# libclang13-19.1.7    | 25.5 MB   | ##5        |  25%
#
#
#
# icu-75.1             | 13.9 MB   | ####6      |  46%
#
# pillow-11.1.0        | 39.9 MB   | #1         |  11%
# qt6-main-6.8.1       | 87.8 MB   | 8          |   8%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | #####5     |  56%
#
#
# libclang13-19.1.7    | 25.5 MB   | ##6        |  26%
#
#
#
# icu-75.1             | 13.9 MB   | ####8      |  48%
#
# pillow-11.1.0        | 39.9 MB   | #1         |  12%
# qt6-main-6.8.1       | 87.8 MB   | 8          |   9%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | #####8     |  58%
#
#
#
# icu-75.1             | 13.9 MB   | ####9      |  50%
#
# pillow-11.1.0        | 39.9 MB   | #1         |  12%
#
#
# libclang13-19.1.7    | 25.5 MB   | ##7        |  27%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ######     |  60%
# qt6-main-6.8.1       | 87.8 MB   | 9          |   9%
#
# pillow-11.1.0        | 39.9 MB   | #2         |  12%
#
#
#
# icu-75.1             | 13.9 MB   | #####1     |  52%
#
#
# libclang13-19.1.7    | 25.5 MB   | ##8        |  28%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ######2    |  63%
# qt6-main-6.8.1       | 87.8 MB   | 9          |  10%
#
# pillow-11.1.0        | 39.9 MB   | #2         |  13%
#
#
#
# icu-75.1             | 13.9 MB   | #####3     |  54%
#
#
# libclang13-19.1.7    | 25.5 MB   | ##9        |  29%
# qt6-main-6.8.1       | 87.8 MB   | 9          |  10%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ######5    |  65%
#
# pillow-11.1.0        | 39.9 MB   | #3         |  13%
#
#
#
# icu-75.1             | 13.9 MB   | #####5     |  55%
# qt6-main-6.8.1       | 87.8 MB   | #          |  10%
#
#
# libclang13-19.1.7    | 25.5 MB   | ##9        |  30%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ######7    |  68%
#
#
#
# icu-75.1             | 13.9 MB   | #####6     |  57%
#
# pillow-11.1.0        | 39.9 MB   | #3         |  14%
# qt6-main-6.8.1       | 87.8 MB   | #          |  11%
#
#
# libclang13-19.1.7    | 25.5 MB   | ###        |  31%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | #######    |  70%
#
#
#
# icu-75.1             | 13.9 MB   | #####8     |  59%
#
# pillow-11.1.0        | 39.9 MB   | #4         |  14%
# qt6-main-6.8.1       | 87.8 MB   | #1         |  11%
#
#
# libclang13-19.1.7    | 25.5 MB   | ###1       |  31%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | #######2   |  73%
#
#
#
# icu-75.1             | 13.9 MB   | ######     |  60%
#
# pillow-11.1.0        | 39.9 MB   | #4         |  15%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | #######5   |  75%
#
#
# libclang13-19.1.7    | 25.5 MB   | ###2       |  32%
# qt6-main-6.8.1       | 87.8 MB   | #1         |  12%
#
#
#
# icu-75.1             | 13.9 MB   | ######1    |  62%
#
# pillow-11.1.0        | 39.9 MB   | #5         |  15%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | #######8   |  79%
#
#
# libclang13-19.1.7    | 25.5 MB   | ###2       |  33%
# qt6-main-6.8.1       | 87.8 MB   | #2         |  12%
#
# pillow-11.1.0        | 39.9 MB   | #5         |  16%
#
#
#
# icu-75.1             | 13.9 MB   | ######3    |  64%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ########1  |  82%
#
#
# libclang13-19.1.7    | 25.5 MB   | ###3       |  33%
# qt6-main-6.8.1       | 87.8 MB   | #2         |  13%
#
# pillow-11.1.0        | 39.9 MB   | #6         |  16%
#
#
#
# icu-75.1             | 13.9 MB   | ######5    |  65%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ########4  |  84%
# qt6-main-6.8.1       | 87.8 MB   | #2         |  13%
#
# pillow-11.1.0        | 39.9 MB   | #6         |  17%
#
#
#
# icu-75.1             | 13.9 MB   | ######6    |  67%
#
#
# libclang13-19.1.7    | 25.5 MB   | ###4       |  34%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ########7  |  87%
# qt6-main-6.8.1       | 87.8 MB   | #3         |  13%
#
# pillow-11.1.0        | 39.9 MB   | #7         |  17%
#
#
#
# icu-75.1             | 13.9 MB   | ######8    |  68%
#
#
# libclang13-19.1.7    | 25.5 MB   | ###5       |  35%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | #########  |  91%
# qt6-main-6.8.1       | 87.8 MB   | #3         |  14%
#
# pillow-11.1.0        | 39.9 MB   | #7         |  18%
#
#
#
# icu-75.1             | 13.9 MB   | #######    |  70%
#
#
# libclang13-19.1.7    | 25.5 MB   | ###5       |  36%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | #########3 |  94%
# qt6-main-6.8.1       | 87.8 MB   | #4         |  14%
#
# pillow-11.1.0        | 39.9 MB   | #8         |  19%
#
#
#
# icu-75.1             | 13.9 MB   | #######1   |  72%
#
#
# libclang13-19.1.7    | 25.5 MB   | ###6       |  37%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | #########6 |  97%
# qt6-main-6.8.1       | 87.8 MB   | #4         |  15%
#
# pillow-11.1.0        | 39.9 MB   | #9         |  19%
#
#
# libclang13-19.1.7    | 25.5 MB   | ###7       |  37%
#
#
#
# icu-75.1             | 13.9 MB   | #######3   |  73%
# qt6-main-6.8.1       | 87.8 MB   | #4         |  15%
#
# pillow-11.1.0        | 39.9 MB   | #9         |  20%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ########## | 100%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ########## | 100%
#
#
# libclang13-19.1.7    | 25.5 MB   | ###8       |  38%
#
#
#
# icu-75.1             | 13.9 MB   | #######5   |  75%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    |            |   0%
# qt6-main-6.8.1       | 87.8 MB   | #5         |  15%
#
# pillow-11.1.0        | 39.9 MB   | ##         |  20%
#
#
# libclang13-19.1.7    | 25.5 MB   | ###8       |  39%
#
#
#
# icu-75.1             | 13.9 MB   | #######6   |  77%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | 3          |   3%
# qt6-main-6.8.1       | 87.8 MB   | #5         |  16%
#
# pillow-11.1.0        | 39.9 MB   | ##         |  21%
#
#
# libclang13-19.1.7    | 25.5 MB   | ###9       |  40%
#
#
#
# icu-75.1             | 13.9 MB   | #######8   |  78%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | 7          |   7%
# qt6-main-6.8.1       | 87.8 MB   | #6         |  16%
#
# pillow-11.1.0        | 39.9 MB   | ##1        |  22%
#
#
# libclang13-19.1.7    | 25.5 MB   | ####       |  40%
#
#
#
# icu-75.1             | 13.9 MB   | #######9   |  80%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | #          |  11%
# qt6-main-6.8.1       | 87.8 MB   | #6         |  17%
#
# pillow-11.1.0        | 39.9 MB   | ##2        |  22%
#
#
# libclang13-19.1.7    | 25.5 MB   | ####1      |  41%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | #3         |  14%
#
#
#
# icu-75.1             | 13.9 MB   | ########1  |  81%
# qt6-main-6.8.1       | 87.8 MB   | #6         |  17%
#
# pillow-11.1.0        | 39.9 MB   | ##2        |  23%
#
#
# libclang13-19.1.7    | 25.5 MB   | ####1      |  42%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | #7         |  18%
#
#
#
# icu-75.1             | 13.9 MB   | ########2  |  83%
# qt6-main-6.8.1       | 87.8 MB   | #7         |  17%
#
#
# libclang13-19.1.7    | 25.5 MB   | ####2      |  42%
#
# pillow-11.1.0        | 39.9 MB   | ##3        |  23%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ##1        |  22%
#
#
#
# icu-75.1             | 13.9 MB   | ########4  |  84%
# qt6-main-6.8.1       | 87.8 MB   | #7         |  18%
#
#
# libclang13-19.1.7    | 25.5 MB   | ####3      |  43%
#
# pillow-11.1.0        | 39.9 MB   | ##3        |  24%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ##5        |  25%
#
#
#
# icu-75.1             | 13.9 MB   | ########5  |  86%
# qt6-main-6.8.1       | 87.8 MB   | #8         |  18%
#
#
# libclang13-19.1.7    | 25.5 MB   | ####3      |  44%
#
# pillow-11.1.0        | 39.9 MB   | ##4        |  24%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ##9        |  29%
#
#
#
# icu-75.1             | 13.9 MB   | ########7  |  87%
# qt6-main-6.8.1       | 87.8 MB   | #8         |  18%
#
#
# libclang13-19.1.7    | 25.5 MB   | ####4      |  45%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ###2       |  33%
#
#
#
# icu-75.1             | 13.9 MB   | ########8  |  89%
#
# pillow-11.1.0        | 39.9 MB   | ##4        |  25%
# qt6-main-6.8.1       | 87.8 MB   | #8         |  19%
#
#
# libclang13-19.1.7    | 25.5 MB   | ####5      |  45%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ###6       |  36%
#
#
#
# icu-75.1             | 13.9 MB   | #########  |  91%
#
# pillow-11.1.0        | 39.9 MB   | ##5        |  25%
# qt6-main-6.8.1       | 87.8 MB   | #9         |  19%
#
#
# libclang13-19.1.7    | 25.5 MB   | ####6      |  46%
#
#
#
# icu-75.1             | 13.9 MB   | #########2 |  92%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ###9       |  40%
#
# pillow-11.1.0        | 39.9 MB   | ##5        |  26%
# qt6-main-6.8.1       | 87.8 MB   | #9         |  20%
#
#
# libclang13-19.1.7    | 25.5 MB   | ####6      |  47%
#
#
#
# icu-75.1             | 13.9 MB   | #########3 |  94%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ####3      |  43%
#
# pillow-11.1.0        | 39.9 MB   | ##6        |  26%
# qt6-main-6.8.1       | 87.8 MB   | #9         |  20%
#
#
# libclang13-19.1.7    | 25.5 MB   | ####7      |  47%
#
#
#
# icu-75.1             | 13.9 MB   | #########5 |  95%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ####6      |  47%
#
# pillow-11.1.0        | 39.9 MB   | ##6        |  27%
# qt6-main-6.8.1       | 87.8 MB   | ##         |  20%
#
#
# libclang13-19.1.7    | 25.5 MB   | ####8      |  48%
#
#
#
# icu-75.1             | 13.9 MB   | #########6 |  97%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | #####      |  51%
#
# pillow-11.1.0        | 39.9 MB   | ##7        |  27%
# qt6-main-6.8.1       | 87.8 MB   | ##         |  21%
#
#
# libclang13-19.1.7    | 25.5 MB   | ####8      |  49%
#
#
#
# icu-75.1             | 13.9 MB   | #########8 |  98%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | #####4     |  54%
# qt6-main-6.8.1       | 87.8 MB   | ##1        |  21%
#
# pillow-11.1.0        | 39.9 MB   | ##7        |  28%
#
#
# libclang13-19.1.7    | 25.5 MB   | ####9      |  50%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | #####7     |  58%
# qt6-main-6.8.1       | 87.8 MB   | ##1        |  21%
#
# pillow-11.1.0        | 39.9 MB   | ##8        |  28%
#
#
# libclang13-19.1.7    | 25.5 MB   | #####      |  51%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ######1    |  62%
# qt6-main-6.8.1       | 87.8 MB   | ##1        |  22%
#
# pillow-11.1.0        | 39.9 MB   | ##8        |  29%
#
#
# libclang13-19.1.7    | 25.5 MB   | #####1     |  51%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ######6    |  66%
# qt6-main-6.8.1       | 87.8 MB   | ##2        |  22%
#
# pillow-11.1.0        | 39.9 MB   | ##9        |  29%
#
#
#
# icu-75.1             | 13.9 MB   | ########## | 100%
#
#
#
# icu-75.1             | 13.9 MB   | ########## | 100%
#
#
# libclang13-19.1.7    | 25.5 MB   | #####2     |  52%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | #######    |  70%
# qt6-main-6.8.1       | 87.8 MB   | ##2        |  23%
#
# pillow-11.1.0        | 39.9 MB   | ##9        |  30%
#
#
# libclang13-19.1.7    | 25.5 MB   | #####3     |  53%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | #######4   |  75%
# qt6-main-6.8.1       | 87.8 MB   | ##3        |  23%
#
# pillow-11.1.0        | 39.9 MB   | ###        |  31%
#
#
# libclang13-19.1.7    | 25.5 MB   | #####4     |  54%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | #######8   |  79%
# qt6-main-6.8.1       | 87.8 MB   | ##3        |  24%
#
# pillow-11.1.0        | 39.9 MB   | ###1       |  31%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ########3  |  83%
#
#
# libclang13-19.1.7    | 25.5 MB   | #####4     |  55%
# qt6-main-6.8.1       | 87.8 MB   | ##4        |  24%
#
#
#
#
#
#
# libmamba-1.5.11      | 3.9 MB    |            |   0%
#
# pillow-11.1.0        | 39.9 MB   | ###1       |  32%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ########7  |  88%
#
#
# libclang13-19.1.7    | 25.5 MB   | #####5     |  56%
#
#
#
#
#
#
# libmamba-1.5.11      | 3.9 MB    | 9          |   9%
#
#
#
#
#
#
# libmamba-1.5.11      | 3.9 MB    | #8         |  19%
# qt6-main-6.8.1       | 87.8 MB   | ##4        |  25%
#
# pillow-11.1.0        | 39.9 MB   | ###2       |  32%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | #########1 |  91%
#
#
# libclang13-19.1.7    | 25.5 MB   | #####6     |  57%
#
#
#
#
#
#
# libmamba-1.5.11      | 3.9 MB    | ###8       |  38%
# qt6-main-6.8.1       | 87.8 MB   | ##5        |  25%
#
# pillow-11.1.0        | 39.9 MB   | ###2       |  33%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | #########4 |  95%
#
#
# libclang13-19.1.7    | 25.5 MB   | #####7     |  57%
#
#
#
#
#
#
# libmamba-1.5.11      | 3.9 MB    | ####9      |  50%
# qt6-main-6.8.1       | 87.8 MB   | ##5        |  25%
#
# pillow-11.1.0        | 39.9 MB   | ###3       |  33%
#
#
#
#
#
#
# libmamba-1.5.11      | 3.9 MB    | ######5    |  66%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | #########7 |  98%
#
#
# libclang13-19.1.7    | 25.5 MB   | #####7     |  58%
#
#
#
#
#
#
# libmamba-1.5.11      | 3.9 MB    | ########   |  80%
# qt6-main-6.8.1       | 87.8 MB   | ##5        |  26%
#
# pillow-11.1.0        | 39.9 MB   | ###3       |  33%
#
#
#
#
# pyside6-6.8.1        | 9.3 MB    | ########## | 100%
#
#
# libclang13-19.1.7    | 25.5 MB   | #####8     |  58%
# qt6-main-6.8.1       | 87.8 MB   | ##5        |  26%
#
#
#
#
#
#
# libmamba-1.5.11      | 3.9 MB    | ########## | 100%
#
#
#
#
#
#
# libmamba-1.5.11      | 3.9 MB    | ########## | 100%
#
# pillow-11.1.0        | 39.9 MB   | ###3       |  34%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ########## | 100%
#
#
# libclang13-19.1.7    | 25.5 MB   | #####9     |  59%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    |            |   0%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    |            |   0%
# qt6-main-6.8.1       | 87.8 MB   | ##6        |  26%
#
# pillow-11.1.0        | 39.9 MB   | ###4       |  34%
#
#
# libclang13-19.1.7    | 25.5 MB   | #####9     |  60%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    | 6          |   6%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | 7          |   7%
# qt6-main-6.8.1       | 87.8 MB   | ##6        |  27%
#
# pillow-11.1.0        | 39.9 MB   | ###4       |  35%
#
#
# libclang13-19.1.7    | 25.5 MB   | ######     |  61%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    | #1         |  12%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #3         |  13%
# qt6-main-6.8.1       | 87.8 MB   | ##7        |  27%
#
# pillow-11.1.0        | 39.9 MB   | ###5       |  35%
#
#
# libclang13-19.1.7    | 25.5 MB   | ######1    |  61%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    | #8         |  18%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #9         |  20%
# qt6-main-6.8.1       | 87.8 MB   | ##7        |  28%
#
# pillow-11.1.0        | 39.9 MB   | ###5       |  36%
#
#
# libclang13-19.1.7    | 25.5 MB   | ######1    |  62%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    | ##4        |  24%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ##6        |  26%
# qt6-main-6.8.1       | 87.8 MB   | ##8        |  28%
#
# pillow-11.1.0        | 39.9 MB   | ###6       |  37%
#
#
# libclang13-19.1.7    | 25.5 MB   | ######2    |  63%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    | ###        |  30%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ###2       |  32%
# qt6-main-6.8.1       | 87.8 MB   | ##8        |  29%
#
# pillow-11.1.0        | 39.9 MB   | ###7       |  37%
#
#
# libclang13-19.1.7    | 25.5 MB   | ######3    |  63%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ###9       |  39%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    | ###5       |  36%
# qt6-main-6.8.1       | 87.8 MB   | ##8        |  29%
#
# pillow-11.1.0        | 39.9 MB   | ###7       |  38%
#
#
# libclang13-19.1.7    | 25.5 MB   | ######3    |  64%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ####6      |  47%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    | ####4      |  45%
#
# pillow-11.1.0        | 39.9 MB   | ###8       |  38%
# qt6-main-6.8.1       | 87.8 MB   | ##9        |  29%
#
#
# libclang13-19.1.7    | 25.5 MB   | ######4    |  65%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #####3     |  53%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    | #####1     |  51%
# qt6-main-6.8.1       | 87.8 MB   | ##9        |  30%
#
# pillow-11.1.0        | 39.9 MB   | ###8       |  39%
#
#
# libclang13-19.1.7    | 25.5 MB   | ######5    |  65%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ######     |  61%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    | #####8     |  58%
#
# pillow-11.1.0        | 39.9 MB   | ###9       |  39%
# qt6-main-6.8.1       | 87.8 MB   | ###        |  30%
#
#
# libclang13-19.1.7    | 25.5 MB   | ######6    |  66%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ######7    |  68%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    | ######4    |  65%
# qt6-main-6.8.1       | 87.8 MB   | ###        |  31%
#
# pillow-11.1.0        | 39.9 MB   | ###9       |  40%
#
#
# libclang13-19.1.7    | 25.5 MB   | ######6    |  67%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #######4   |  75%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    | #######1   |  71%
# qt6-main-6.8.1       | 87.8 MB   | ###1       |  31%
#
# pillow-11.1.0        | 39.9 MB   | ####       |  40%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########1  |  82%
#
#
# libclang13-19.1.7    | 25.5 MB   | ######7    |  67%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    | #######7   |  77%
# qt6-main-6.8.1       | 87.8 MB   | ###1       |  31%
#
# pillow-11.1.0        | 39.9 MB   | ####       |  41%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########8  |  88%
#
#
# libclang13-19.1.7    | 25.5 MB   | ######8    |  68%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    | ########2  |  83%
# qt6-main-6.8.1       | 87.8 MB   | ###1       |  32%
#
# pillow-11.1.0        | 39.9 MB   | ####1      |  41%
#
#
# libclang13-19.1.7    | 25.5 MB   | ######8    |  69%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | #########6 |  96%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    | ########9  |  90%
# qt6-main-6.8.1       | 87.8 MB   | ###2       |  32%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########## | 100%
#
# pillow-11.1.0        | 39.9 MB   | ####1      |  42%
#
#
# libclang13-19.1.7    | 25.5 MB   | ######9    |  70%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    | #########6 |  96%
#
#
#
#
#
#
#
#
#
# fonttools-4.55.8     | 2.3 MB    |            |   1%
# qt6-main-6.8.1       | 87.8 MB   | ###2       |  33%
#
# pillow-11.1.0        | 39.9 MB   | ####2      |  42%
#
#
# libclang13-19.1.7    | 25.5 MB   | #######    |  70%
#
#
#
#
#
#
#
#
#
# fonttools-4.55.8     | 2.3 MB    | #          |  10%
# qt6-main-6.8.1       | 87.8 MB   | ###3       |  33%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    | ########## | 100%
#
# pillow-11.1.0        | 39.9 MB   | ####2      |  43%
#
#
# libclang13-19.1.7    | 25.5 MB   | #######1   |  71%
#
#
#
#
#
#
#
#
#
# fonttools-4.55.8     | 2.3 MB    | ##1        |  21%
# qt6-main-6.8.1       | 87.8 MB   | ###3       |  34%
#
#
# libclang13-19.1.7    | 25.5 MB   | #######2   |  72%
#
# pillow-11.1.0        | 39.9 MB   | ####3      |  44%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | 1          |   1%
#
#
#
#
#
#
#
#
#
# fonttools-4.55.8     | 2.3 MB    | ###        |  31%
# qt6-main-6.8.1       | 87.8 MB   | ###4       |  34%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #6         |  16%
#
#
# libclang13-19.1.7    | 25.5 MB   | #######3   |  73%
#
# pillow-11.1.0        | 39.9 MB   | ####4      |  44%
#
#
#
#
#
#
#
#
#
# fonttools-4.55.8     | 2.3 MB    | ###9       |  40%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##7        |  27%
# qt6-main-6.8.1       | 87.8 MB   | ###4       |  34%
#
#
#
#
#
#
#
#
#
# fonttools-4.55.8     | 2.3 MB    | #####3     |  54%
#
#
# libclang13-19.1.7    | 25.5 MB   | #######4   |  74%
#
#
#
#
#
#
#
#
#
# fonttools-4.55.8     | 2.3 MB    | ######9    |  69%
#
# pillow-11.1.0        | 39.9 MB   | ####4      |  45%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ###7       |  37%
#
#
# libclang13-19.1.7    | 25.5 MB   | #######4   |  75%
#
#
#
#
#
#
#
#
#
# fonttools-4.55.8     | 2.3 MB    | ########5  |  85%
# qt6-main-6.8.1       | 87.8 MB   | ###4       |  35%
#
# pillow-11.1.0        | 39.9 MB   | ####5      |  45%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ####5      |  45%
#
#
# libclang13-19.1.7    | 25.5 MB   | #######5   |  76%
# qt6-main-6.8.1       | 87.8 MB   | ###5       |  35%
#
# pillow-11.1.0        | 39.9 MB   | ####5      |  46%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #####7     |  58%
#
#
#
#
#
#
#
#
#
# fonttools-4.55.8     | 2.3 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# fonttools-4.55.8     | 2.3 MB    | ########## | 100%
#
#
#
# icu-75.1             | 13.9 MB   | ########## | 100%
#
#
# libclang13-19.1.7    | 25.5 MB   | #######6   |  76%
# qt6-main-6.8.1       | 87.8 MB   | ###5       |  36%
#
#
#
#
#
#
# libmamba-1.5.11      | 3.9 MB    | ########## | 100%
#
# pillow-11.1.0        | 39.9 MB   | ####6      |  46%
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 1.5 MB    | 1          |   1%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #######    |  71%
#
#
# libclang13-19.1.7    | 25.5 MB   | #######7   |  77%
# qt6-main-6.8.1       | 87.8 MB   | ###6       |  36%
#
# pillow-11.1.0        | 39.9 MB   | ####6      |  47%
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 1.5 MB    | ##1        |  21%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ########   |  81%
# qt6-main-6.8.1       | 87.8 MB   | ###6       |  36%
#
#
# libclang13-19.1.7    | 25.5 MB   | #######8   |  78%
#
# pillow-11.1.0        | 39.9 MB   | ####7      |  47%
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 1.5 MB    | ####       |  41%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #########2 |  92%
# qt6-main-6.8.1       | 87.8 MB   | ###6       |  37%
#
#
# libclang13-19.1.7    | 25.5 MB   | #######9   |  79%
#
# pillow-11.1.0        | 39.9 MB   | ####7      |  48%
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 1.5 MB    | #####8     |  59%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ########## | 100%
# qt6-main-6.8.1       | 87.8 MB   | ###7       |  37%
#
#
# libclang13-19.1.7    | 25.5 MB   | ########   |  80%
#
# pillow-11.1.0        | 39.9 MB   | ####8      |  48%
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 1.5 MB    | ########2  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.2         | 1.4 MB    | 1          |   1%
#
#
# libclang13-19.1.7    | 25.5 MB   | ########1  |  81%
# qt6-main-6.8.1       | 87.8 MB   | ###7       |  38%
#
# pillow-11.1.0        | 39.9 MB   | ####8      |  49%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.2         | 1.4 MB    | #2         |  13%
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 1.5 MB    | ########## | 100%
#
#
# libclang13-19.1.7    | 25.5 MB   | ########2  |  82%
# qt6-main-6.8.1       | 87.8 MB   | ###8       |  38%
#
# pillow-11.1.0        | 39.9 MB   | ####9      |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.3 MB    | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.2         | 1.4 MB    | ##4        |  25%
#
#
# libclang13-19.1.7    | 25.5 MB   | ########3  |  83%
# qt6-main-6.8.1       | 87.8 MB   | ###8       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.3 MB    | ##1        |  21%
#
# pillow-11.1.0        | 39.9 MB   | ####9      |  50%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.2         | 1.4 MB    | ###7       |  38%
#
#
# libclang13-19.1.7    | 25.5 MB   | ########4  |  84%
#
# pillow-11.1.0        | 39.9 MB   | #####      |  50%
# qt6-main-6.8.1       | 87.8 MB   | ###8       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.3 MB    | ####1      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.2         | 1.4 MB    | ####9      |  50%
#
#
# libclang13-19.1.7    | 25.5 MB   | ########4  |  85%
#
# pillow-11.1.0        | 39.9 MB   | #####1     |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.3 MB    | #####9     |  59%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.2         | 1.4 MB    | ######1    |  62%
# qt6-main-6.8.1       | 87.8 MB   | ###9       |  39%
#
# pillow-11.1.0        | 39.9 MB   | #####1     |  52%
#
#
# libclang13-19.1.7    | 25.5 MB   | ########5  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.3 MB    | #######7   |  77%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.2         | 1.4 MB    | #######6   |  77%
# qt6-main-6.8.1       | 87.8 MB   | ###9       |  40%
#
# pillow-11.1.0        | 39.9 MB   | #####2     |  52%
#
#
# libclang13-19.1.7    | 25.5 MB   | ########7  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.3 MB    | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.2         | 1.4 MB    | ########9  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.3 MB    | ########## | 100%
# qt6-main-6.8.1       | 87.8 MB   | ####       |  40%
#
#
# libclang13-19.1.7    | 25.5 MB   | ########8  |  88%
#
# pillow-11.1.0        | 39.9 MB   | #####2     |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 1.2 MB    | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.2         | 1.4 MB    | ########## | 100%
# qt6-main-6.8.1       | 87.8 MB   | ####       |  41%
#
#
# libclang13-19.1.7    | 25.5 MB   | ########9  |  89%
#
# pillow-11.1.0        | 39.9 MB   | #####3     |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 1.2 MB    | ##4        |  24%
# qt6-main-6.8.1       | 87.8 MB   | ####1      |  41%
#
#
# libclang13-19.1.7    | 25.5 MB   | #########  |  90%
#
# pillow-11.1.0        | 39.9 MB   | #####4     |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 1.2 MB    | ####7      |  47%
# qt6-main-6.8.1       | 87.8 MB   | ####1      |  41%
#
#
# libclang13-19.1.7    | 25.5 MB   | #########  |  91%
#
# pillow-11.1.0        | 39.9 MB   | #####4     |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 1.2 MB    | ######9    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-25.1.1         | 1.1 MB    | 1          |   1%
# qt6-main-6.8.1       | 87.8 MB   | ####1      |  42%
#
#
# libclang13-19.1.7    | 25.5 MB   | #########1 |  92%
#
# pillow-11.1.0        | 39.9 MB   | #####5     |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 1.2 MB    | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-25.1.1         | 1.1 MB    | #6         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 1.2 MB    | ########## | 100%
# qt6-main-6.8.1       | 87.8 MB   | ####2      |  42%
#
#
# libclang13-19.1.7    | 25.5 MB   | #########2 |  93%
#
# pillow-11.1.0        | 39.9 MB   | #####5     |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-25.1.1         | 1.1 MB    | ###4       |  35%
# qt6-main-6.8.1       | 87.8 MB   | ####2      |  43%
#
#
# libclang13-19.1.7    | 25.5 MB   | #########3 |  94%
#
# pillow-11.1.0        | 39.9 MB   | #####6     |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-25.1.1         | 1.1 MB    | #####5     |  56%
# qt6-main-6.8.1       | 87.8 MB   | ####3      |  43%
#
#
# libclang13-19.1.7    | 25.5 MB   | #########4 |  95%
#
# pillow-11.1.0        | 39.9 MB   | #####7     |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-25.1.1         | 1.1 MB    | #######3   |  74%
# qt6-main-6.8.1       | 87.8 MB   | ####3      |  43%
#
#
# libclang13-19.1.7    | 25.5 MB   | #########5 |  96%
#
# pillow-11.1.0        | 39.9 MB   | #####7     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.2.0      | 1.1 MB    | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-25.1.1         | 1.1 MB    | #########4 |  95%
# qt6-main-6.8.1       | 87.8 MB   | ####3      |  44%
#
#
# libclang13-19.1.7    | 25.5 MB   | #########7 |  97%
#
# pillow-11.1.0        | 39.9 MB   | #####8     |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-25.1.1         | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.2.0      | 1.1 MB    | ##8        |  28%
# qt6-main-6.8.1       | 87.8 MB   | ####4      |  44%
#
#
# libclang13-19.1.7    | 25.5 MB   | #########8 |  98%
#
# pillow-11.1.0        | 39.9 MB   | #####9     |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 1.0 MB    | 1          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.2.0      | 1.1 MB    | #####4     |  55%
# qt6-main-6.8.1       | 87.8 MB   | ####4      |  45%
#
# pillow-11.1.0        | 39.9 MB   | #####9     |  60%
#
#
# libclang13-19.1.7    | 25.5 MB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 1.0 MB    | #8         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.2.0      | 1.1 MB    | #######8   |  79%
# qt6-main-6.8.1       | 87.8 MB   | ####5      |  45%
#
#
# libclang13-19.1.7    | 25.5 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 1.0 MB    | ###4       |  35%
#
# pillow-11.1.0        | 39.9 MB   | ######     |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.2.0      | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.2.0      | 1.1 MB    | ########## | 100%
# qt6-main-6.8.1       | 87.8 MB   | ####5      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 1.0 MB    | #####2     |  53%
#
# pillow-11.1.0        | 39.9 MB   | ######     |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 956 KB    | 1          |   2%
# qt6-main-6.8.1       | 87.8 MB   | ####6      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 1.0 MB    | #######5   |  76%
#
# pillow-11.1.0        | 39.9 MB   | ######1    |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 956 KB    | ###3       |  33%
# qt6-main-6.8.1       | 87.8 MB   | ####6      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 1.0 MB    | #########6 |  97%
#
# pillow-11.1.0        | 39.9 MB   | ######2    |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 956 KB    | ######5    |  65%
#
#
# libclang13-19.1.7    | 25.5 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 1.0 MB    | ########## | 100%
# qt6-main-6.8.1       | 87.8 MB   | ####6      |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# pillow-11.1.0        | 39.9 MB   | ######3    |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 956 KB    | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 956 KB    | ########## | 100%
# qt6-main-6.8.1       | 87.8 MB   | ####7      |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# pillow-11.1.0        | 39.9 MB   | ######3    |  64%
# qt6-main-6.8.1       | 87.8 MB   | ####7      |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# pillow-11.1.0        | 39.9 MB   | ######4    |  65%
# qt6-main-6.8.1       | 87.8 MB   | ####8      |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# pillow-11.1.0        | 39.9 MB   | ######5    |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# qt6-main-6.8.1       | 87.8 MB   | ####8      |  49%
#
# pillow-11.1.0        | 39.9 MB   | ######5    |  66%
# qt6-main-6.8.1       | 87.8 MB   | ####9      |  49%
#
# pillow-11.1.0        | 39.9 MB   | ######6    |  67%
# qt6-main-6.8.1       | 87.8 MB   | ####9      |  50%
#
# pillow-11.1.0        | 39.9 MB   | ######7    |  67%
# qt6-main-6.8.1       | 87.8 MB   | #####      |  50%
#
# pillow-11.1.0        | 39.9 MB   | ######8    |  68%
# qt6-main-6.8.1       | 87.8 MB   | #####      |  51%
#
# pillow-11.1.0        | 39.9 MB   | ######8    |  69%
# qt6-main-6.8.1       | 87.8 MB   | #####1     |  51%
#
# pillow-11.1.0        | 39.9 MB   | ######9    |  69%
# qt6-main-6.8.1       | 87.8 MB   | #####1     |  52%
#
# pillow-11.1.0        | 39.9 MB   | #######    |  70%
# qt6-main-6.8.1       | 87.8 MB   | #####2     |  52%
#
# pillow-11.1.0        | 39.9 MB   | #######    |  71%
# qt6-main-6.8.1       | 87.8 MB   | #####2     |  53%
#
# pillow-11.1.0        | 39.9 MB   | #######1   |  72%
# qt6-main-6.8.1       | 87.8 MB   | #####3     |  53%
#
# pillow-11.1.0        | 39.9 MB   | #######2   |  72%
# qt6-main-6.8.1       | 87.8 MB   | #####3     |  54%
#
# pillow-11.1.0        | 39.9 MB   | #######3   |  73%
# qt6-main-6.8.1       | 87.8 MB   | #####4     |  55%
#
#
#
#
#
#
#
# libglib-2.82.2       | 3.6 MB    | ########## | 100%
#
# pillow-11.1.0        | 39.9 MB   | #######3   |  74%
# qt6-main-6.8.1       | 87.8 MB   | #####5     |  55%
#
# pillow-11.1.0        | 39.9 MB   | #######4   |  75%
# qt6-main-6.8.1       | 87.8 MB   | #####5     |  56%
# qt6-main-6.8.1       | 87.8 MB   | #####6     |  56%
#
# pillow-11.1.0        | 39.9 MB   | #######5   |  75%
# qt6-main-6.8.1       | 87.8 MB   | #####6     |  57%
#
# pillow-11.1.0        | 39.9 MB   | #######5   |  76%
# qt6-main-6.8.1       | 87.8 MB   | #####7     |  57%
#
# pillow-11.1.0        | 39.9 MB   | #######6   |  77%
# qt6-main-6.8.1       | 87.8 MB   | #####8     |  58%
#
# pillow-11.1.0        | 39.9 MB   | #######7   |  78%
# qt6-main-6.8.1       | 87.8 MB   | #####8     |  59%
#
# pillow-11.1.0        | 39.9 MB   | #######8   |  78%
# qt6-main-6.8.1       | 87.8 MB   | #####9     |  59%
#
# pillow-11.1.0        | 39.9 MB   | #######9   |  79%
# qt6-main-6.8.1       | 87.8 MB   | ######     |  60%
#
# pillow-11.1.0        | 39.9 MB   | #######9   |  80%
# qt6-main-6.8.1       | 87.8 MB   | ######     |  61%
#
# pillow-11.1.0        | 39.9 MB   | ########   |  81%
# qt6-main-6.8.1       | 87.8 MB   | ######1    |  62%
#
# pillow-11.1.0        | 39.9 MB   | ########1  |  82%
# qt6-main-6.8.1       | 87.8 MB   | ######2    |  62%
#
# pillow-11.1.0        | 39.9 MB   | ########2  |  82%
# qt6-main-6.8.1       | 87.8 MB   | ######2    |  63%
#
# pillow-11.1.0        | 39.9 MB   | ########3  |  83%
# qt6-main-6.8.1       | 87.8 MB   | ######3    |  64%
#
# pillow-11.1.0        | 39.9 MB   | ########3  |  84%
# qt6-main-6.8.1       | 87.8 MB   | ######4    |  64%
#
# pillow-11.1.0        | 39.9 MB   | ########4  |  85%
# qt6-main-6.8.1       | 87.8 MB   | ######4    |  65%
#
# pillow-11.1.0        | 39.9 MB   | ########5  |  85%
# qt6-main-6.8.1       | 87.8 MB   | ######5    |  66%
#
# pillow-11.1.0        | 39.9 MB   | ########6  |  86%
# qt6-main-6.8.1       | 87.8 MB   | ######6    |  66%
#
# pillow-11.1.0        | 39.9 MB   | ########6  |  87%
# qt6-main-6.8.1       | 87.8 MB   | ######6    |  67%
# qt6-main-6.8.1       | 87.8 MB   | ######7    |  68%
#
# pillow-11.1.0        | 39.9 MB   | ########8  |  88%
# qt6-main-6.8.1       | 87.8 MB   | ######8    |  69%
#
# pillow-11.1.0        | 39.9 MB   | ########8  |  89%
#
# pillow-11.1.0        | 39.9 MB   | ########9  |  90%
# qt6-main-6.8.1       | 87.8 MB   | ######9    |  70%
# qt6-main-6.8.1       | 87.8 MB   | #######    |  70%
#
# pillow-11.1.0        | 39.9 MB   | #########  |  91%
# qt6-main-6.8.1       | 87.8 MB   | #######1   |  71%
#
# pillow-11.1.0        | 39.9 MB   | #########1 |  92%
# qt6-main-6.8.1       | 87.8 MB   | #######2   |  72%
#
# pillow-11.1.0        | 39.9 MB   | #########2 |  93%
# qt6-main-6.8.1       | 87.8 MB   | #######2   |  73%
#
# pillow-11.1.0        | 39.9 MB   | #########3 |  94%
# qt6-main-6.8.1       | 87.8 MB   | #######3   |  74%
#
# pillow-11.1.0        | 39.9 MB   | #########4 |  95%
# qt6-main-6.8.1       | 87.8 MB   | #######4   |  75%
#
# pillow-11.1.0        | 39.9 MB   | #########5 |  96%
# qt6-main-6.8.1       | 87.8 MB   | #######5   |  76%
#
# pillow-11.1.0        | 39.9 MB   | #########6 |  97%
# qt6-main-6.8.1       | 87.8 MB   | #######6   |  77%
#
# pillow-11.1.0        | 39.9 MB   | #########7 |  98%
# qt6-main-6.8.1       | 87.8 MB   | #######7   |  77%
#
# pillow-11.1.0        | 39.9 MB   | #########8 |  99%
# qt6-main-6.8.1       | 87.8 MB   | #######8   |  78%
#
# pillow-11.1.0        | 39.9 MB   | #########9 |  99%
# qt6-main-6.8.1       | 87.8 MB   | #######9   |  79%
# qt6-main-6.8.1       | 87.8 MB   | ########   |  80%
# qt6-main-6.8.1       | 87.8 MB   | ########1  |  82%
# qt6-main-6.8.1       | 87.8 MB   | ########2  |  83%
# qt6-main-6.8.1       | 87.8 MB   | ########3  |  84%
# qt6-main-6.8.1       | 87.8 MB   | ########5  |  85%
# qt6-main-6.8.1       | 87.8 MB   | ########6  |  87%
# qt6-main-6.8.1       | 87.8 MB   | ########7  |  88%
# qt6-main-6.8.1       | 87.8 MB   | ########9  |  89%
# qt6-main-6.8.1       | 87.8 MB   | #########  |  91%
#
# pillow-11.1.0        | 39.9 MB   | ########## | 100%
# qt6-main-6.8.1       | 87.8 MB   | #########1 |  92%
# qt6-main-6.8.1       | 87.8 MB   | #########3 |  93%
# qt6-main-6.8.1       | 87.8 MB   | #########4 |  94%
# qt6-main-6.8.1       | 87.8 MB   | #########5 |  96%
# qt6-main-6.8.1       | 87.8 MB   | #########7 |  97%
# qt6-main-6.8.1       | 87.8 MB   | #########8 |  98%
# qt6-main-6.8.1       | 87.8 MB   | #########9 | 100%
#
#
#
#
#
# matplotlib-base-3.10 | 7.6 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# fonttools-4.55.8     | 2.3 MB    | ########## | 100%
# qt6-main-6.8.1       | 87.8 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 1.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# tk-8.6.13            | 3.3 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.2         | 1.4 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 1.3 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-10.2.0      | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 1.0 MB    | ########## | 100%
#
#
# libclang13-19.1.7    | 25.5 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# conda-25.1.1         | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 956 KB    | ########## | 100%
#
# pillow-11.1.0        | 39.9 MB   | ########## | 100%
# qt6-main-6.8.1       | 87.8 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import matplotlib.pyplot as plt
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.scatter(x, y_1, label='Y values',
         color='hotpink')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.savefig('test graph')
plt.show()

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B46D-3602
#
#  Directory of C:\Users\Admin\Desktop\learning-portfolio-2025-january-eggvoki\5.1_functions
#
# 02/07/2025  05:11 PM    <DIR>          .
# 02/07/2025  05:11 PM    <DIR>          ..
# 02/06/2025  05:08 PM    <DIR>          .ipynb_checkpoints
# 02/07/2025  05:11 PM           173,246 functions_(good).ipynb
# 02/06/2025  05:08 PM            11,621 functions_(need).ipynb
# 01/15/2025  08:53 AM             2,920 functions_(nice).ipynb
# 02/07/2025  05:09 PM            15,188 test graph.png
#                4 File(s)        202,975 bytes
#                3 Dir(s)  136,517,316,608 bytes free

# %%
def my_function(angle, trig_function):
    return trig_function(angle)
import numpy as np
# Let's use the function
my_function(np.pi/2, np.sin)
# Out:
# np.float64(1.0)

# %%
my_function(np.pi/2, np.cos)
# Out:
# np.float64(6.123233995736766e-17)

# %%
my_function(np.pi/2, lambda x: np.cos(2*x))
# Out:
# np.float64(-1.0)

# %%
x,y,z=[1,2,3]
x,y,z
# Out:
# (1, 2, 3)

# %%
x,y,z=np.array([1,2,3])
x,y,z
# Out:
# (np.int64(1), np.int64(2), np.int64(3))

# %%
x,*y,z=np.array([1,2,3,4,5])
x,y,z
# Out:
# (np.int64(1), [np.int64(2), np.int64(3), np.int64(4)], np.int64(5))

# %%
x,*_,y=[1,2,3,4,5]
x,y
# Out:
# (1, 5)
